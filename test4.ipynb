# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
from apps.onpe.client import headers, cookies, get_resultados_onpe
from pydantic import BaseModel, computed_field, ConfigDict, Field, model_validator
from typing import Annotated, Self, Literal
import requests
from apps.onpe.enums import Eleccion, AmbitoGeografico, UbigeoNivel1, TipoFiltro, UbigeoNivel2, UbigeoNivel3
from apps.onpe.schemas import ConsultaElectoral
import re
import pandas as pd
from core.settings import settings
from enum import Enum
import matplotlib.pyplot as plt
import seaborn as sns

# %%
all_data = []

for ubigeo3 in UbigeoNivel3:
    consulta_electoral = ConsultaElectoral(eleccion=Eleccion.PRESIDENCIAL, ubigeo_3=ubigeo3)

    data_resumen = get_resultados_onpe(consulta_electoral, mode='resumen')['data']
    data_detalle = get_resultados_onpe(consulta_electoral, mode='detalle')['data']

    actas_contabilizadas_porcentaje = data_resumen['actasContabilizadas']

    if actas_contabilizadas_porcentaje == 0:
        print(f"Ubigeo {ubigeo3.name}: No se han contabilizado actas aún. Proyectando resultados...")
        total_actas = data_resumen['totalActas']

        # Calcular segun ubigeo nivel 2
        ubigeo_nivel_2 = ubigeo3.nivel2
        consulta_ubigeo_nivel_2 = ConsultaElectoral(eleccion=Eleccion.PRESIDENCIAL, ubigeo_2=ubigeo_nivel_2)
        nivel_2_resumen = get_resultados_onpe(consulta_ubigeo_nivel_2, mode='resumen')['data']
        nivel_2_detalle = get_resultados_onpe(consulta_ubigeo_nivel_2, mode='detalle')['data']

        nivel_2_actas_porcentaje = nivel_2_resumen['actasContabilizadas']

        if nivel_2_actas_porcentaje == 0:
            print(f"Ubigeo {ubigeo_nivel_2.name}: No se han contabilizado actas aún en el nivel2. Proyectando resultados...")
            # Calcular segun ubigeo nivel 1
            ubigeo_nivel_1 = ubigeo_nivel_2.nivel1
            consulta_ubigeo_nivel_1 = ConsultaElectoral(eleccion=Eleccion.PRESIDENCIAL, ubigeo=ubigeo_nivel_1)
            nivel_1_resumen = get_resultados_onpe(consulta_ubigeo_nivel_1, mode='resumen')['data']
            nivel_1_detalle = get_resultados_onpe(consulta_ubigeo_nivel_1, mode='detalle')['data']

            nivel_1_actas_porcentaje = nivel_1_resumen['actasContabilizadas']
            nivel_1_jp_votos = next(d['totalVotosValidos'] for d in nivel_1_detalle if d['nombreAgrupacionPolitica'] == 'JUNTOS POR EL PERÚ')
            nivel_1_porky_votos = next(d['totalVotosValidos'] for d in nivel_1_detalle if d['nombreAgrupacionPolitica'] == 'RENOVACIÓN POPULAR')

            nivel_1_jp_votos_proyectados = int(nivel_1_jp_votos / nivel_1_actas_porcentaje * 100)
            nivel_1_porky_votos_proyectados = int(nivel_1_porky_votos / nivel_1_actas_porcentaje * 100)

            total_actas_nivel_1 = nivel_1_resumen['totalActas']

            nivel_2_jp_votos_proyectados = int(nivel_1_jp_votos_proyectados / total_actas_nivel_1 * total_actas)
            nivel_2_porky_votos_proyectados = int(nivel_1_porky_votos_proyectados / total_actas_nivel_1 * total_actas)

            jp_data = {
                'nombreAgrupacionPolitica': 'JUNTOS POR EL PERÚ',
                'ubigeo1': ubigeo_nivel_1.name,
                'ubigeo2': ubigeo_nivel_2.name,
                'ubigeo3': ubigeo3.name,
                'actualVotosValidos': nivel_2_jp_votos_proyectados,
                'proyeccionVotosValidos': nivel_2_jp_votos_proyectados
            }

            porky_data = {
                'nombreAgrupacionPolitica': 'RENOVACIÓN POPULAR',
                'ubigeo1': ubigeo_nivel_1.name,
                'ubigeo2': ubigeo_nivel_2.name,
                'ubigeo3': ubigeo3.name,
                'actualVotosValidos': nivel_2_porky_votos_proyectados,
                'proyeccionVotosValidos': nivel_2_porky_votos_proyectados
            }
            all_data.extend([jp_data, porky_data])
            continue
        
        nivel_2_jp_votos = next(d['totalVotosValidos'] for d in nivel_2_detalle if d['nombreAgrupacionPolitica'] == 'JUNTOS POR EL PERÚ')
        nivel_2_porky_votos = next(d['totalVotosValidos'] for d in nivel_2_detalle if d['nombreAgrupacionPolitica'] == 'RENOVACIÓN POPULAR')

        nivel_2_jp_votos_proyectados = int(nivel_2_jp_votos / nivel_2_actas_porcentaje * 100)
        nivel_2_porky_votos_proyectados = int(nivel_2_porky_votos / nivel_2_actas_porcentaje * 100)

        total_actas_nivel_2 = nivel_2_resumen['totalActas']

        nivel_2_jp_votos_proyectados = int(nivel_2_jp_votos_proyectados / total_actas_nivel_2 * total_actas)
        nivel_2_porky_votos_proyectados = int(nivel_2_porky_votos_proyectados / total_actas_nivel_2 * total_actas)

        jp_data = {
            'nombreAgrupacionPolitica': 'JUNTOS POR EL PERÚ',
            'ubigeo1': ubigeo_nivel_2.nivel1.name,
            'ubigeo2': ubigeo_nivel_2.name,
            'ubigeo3': ubigeo3.name,
            'actualVotosValidos': nivel_2_jp_votos_proyectados,
            'proyeccionVotosValidos': nivel_2_jp_votos_proyectados
        }

        porky_data = {
            'nombreAgrupacionPolitica': 'RENOVACIÓN POPULAR',
            'ubigeo1': ubigeo_nivel_2.nivel1.name,
            'ubigeo2': ubigeo_nivel_2.name,
            'ubigeo3': ubigeo3.name,
            'actualVotosValidos': nivel_2_porky_votos_proyectados,
            'proyeccionVotosValidos': nivel_2_porky_votos_proyectados
        }
        all_data.extend([jp_data, porky_data])
        continue

    data_for_extend = [{
        'nombreAgrupacionPolitica': data['nombreAgrupacionPolitica'],
        'ubigeo1': consulta_electoral.ubigeo.name,
        'ubigeo2': consulta_electoral.ubigeo_2.name,
        'ubigeo3': consulta_electoral.ubigeo_3.name,
        'actualVotosValidos': data['totalVotosValidos'],
        'proyeccionVotosValidos': int(data['totalVotosValidos'] / actas_contabilizadas_porcentaje * 100)
    } for data in data_detalle]
    all_data.extend(data_for_extend)
    print(f"{len(all_data)} registros procesados")

df_proyeccion = pd.DataFrame(all_data)
# Out:
# 38 registros procesados
# 76 registros procesados
# 114 registros procesados
# 152 registros procesados
# 190 registros procesados
# 228 registros procesados
# 266 registros procesados
# 304 registros procesados
# 342 registros procesados
# 380 registros procesados
# 418 registros procesados
# 456 registros procesados
# 494 registros procesados
# 532 registros procesados
# 570 registros procesados
# 608 registros procesados
# 646 registros procesados
# 684 registros procesados
# 722 registros procesados
# 760 registros procesados
# 798 registros procesados
# 836 registros procesados
# 874 registros procesados
# 912 registros procesados
# 950 registros procesados
# 988 registros procesados
# 1026 registros procesados
# 1064 registros procesados
# 1102 registros procesados
# 1140 registros procesados
# 1178 registros procesados
# 1216 registros procesados
# 1254 registros procesados
# 1292 registros procesados
# 1330 registros procesados
# 1368 registros procesados
# 1406 registros procesados
# 1444 registros procesados
# 1482 registros procesados
# 1520 registros procesados
# 1558 registros procesados
# 1596 registros procesados
# 1634 registros procesados
# 1672 registros procesados
# 1710 registros procesados
# 1748 registros procesados
# 1786 registros procesados
# 1824 registros procesados
# 1862 registros procesados
# 1900 registros procesados
# 1938 registros procesados
# 1976 registros procesados
# 2014 registros procesados
# 2052 registros procesados
# 2090 registros procesados
# 2128 registros procesados
# 2166 registros procesados
# 2204 registros procesados
# 2242 registros procesados
# 2280 registros procesados
# 2318 registros procesados
# 2356 registros procesados
# 2394 registros procesados
# 2432 registros procesados
# 2470 registros procesados
# 2508 registros procesados
# 2546 registros procesados
# 2584 registros procesados
# 2622 registros procesados
# 2660 registros procesados
# 2698 registros procesados
# 2736 registros procesados
# 2774 registros procesados
# 2812 registros procesados
# 2850 registros procesados
# 2888 registros procesados
# 2926 registros procesados
# 2964 registros procesados
# 3002 registros procesados
# 3040 registros procesados
# 3078 registros procesados
# 3116 registros procesados
# 3154 registros procesados
# 3192 registros procesados
# 3230 registros procesados
# 3268 registros procesados
# 3306 registros procesados
# 3344 registros procesados
# 3382 registros procesados
# 3420 registros procesados
# 3458 registros procesados
# 3496 registros procesados
# 3534 registros procesados
# 3572 registros procesados
# 3610 registros procesados
# 3648 registros procesados
# 3686 registros procesados
# 3724 registros procesados
# 3762 registros procesados
# 3800 registros procesados
# 3838 registros procesados
# 3876 registros procesados
# 3914 registros procesados
# 3952 registros procesados
# 3990 registros procesados
# 4028 registros procesados
# 4066 registros procesados
# 4104 registros procesados
# 4142 registros procesados
# 4180 registros procesados
# 4218 registros procesados
# 4256 registros procesados
# 4294 registros procesados
# 4332 registros procesados
# 4370 registros procesados
# 4408 registros procesados
# 4446 registros procesados
# 4484 registros procesados
# 4522 registros procesados
# 4560 registros procesados
# 4598 registros procesados
# 4636 registros procesados
# 4674 registros procesados
# 4712 registros procesados
# 4750 registros procesados
# 4788 registros procesados
# 4826 registros procesados
# 4864 registros procesados
# 4902 registros procesados
# 4940 registros procesados
# 4978 registros procesados
# 5016 registros procesados
# 5054 registros procesados
# 5092 registros procesados
# 5130 registros procesados
# 5168 registros procesados
# 5206 registros procesados
# 5244 registros procesados
# 5282 registros procesados
# 5320 registros procesados
# 5358 registros procesados
# 5396 registros procesados
# 5434 registros procesados
# 5472 registros procesados
# 5510 registros procesados
# 5548 registros procesados
# 5586 registros procesados
# 5624 registros procesados
# 5662 registros procesados
# 5700 registros procesados
# 5738 registros procesados
# 5776 registros procesados
# 5814 registros procesados
# 5852 registros procesados
# 5890 registros procesados
# 5928 registros procesados
# 5966 registros procesados
# 6004 registros procesados
# 6042 registros procesados
# 6080 registros procesados
# 6118 registros procesados
# 6156 registros procesados
# 6194 registros procesados
# 6232 registros procesados
# 6270 registros procesados
# 6308 registros procesados
# 6346 registros procesados
# 6384 registros procesados
# 6422 registros procesados
# 6460 registros procesados
# 6498 registros procesados
# 6536 registros procesados
# 6574 registros procesados
# 6612 registros procesados
# 6650 registros procesados
# 6688 registros procesados
# 6726 registros procesados
# 6764 registros procesados
# 6802 registros procesados
# 6840 registros procesados
# 6878 registros procesados
# 6916 registros procesados
# 6954 registros procesados
# 6992 registros procesados
# 7030 registros procesados
# 7068 registros procesados
# Ubigeo CAJAMARQUILLA: No se han contabilizado actas aún. Proyectando resultados...
# 7108 registros procesados
# 7146 registros procesados
# Ubigeo CONGAS: No se han contabilizado actas aún. Proyectando resultados...
# Ubigeo LLIPA: No se han contabilizado actas aún. Proyectando resultados...
# 7188 registros procesados
# Ubigeo SAN_CRISTOBAL_DE_RAJAN: No se han contabilizado actas aún. Proyectando resultados...
# 7228 registros procesados
# Ubigeo SANTIAGO_DE_CHILCAS: No se han contabilizado actas aún. Proyectando resultados...
# 7268 registros procesados
# 7306 registros procesados
# 7344 registros procesados
# 7382 registros procesados
# 7420 registros procesados
# 7458 registros procesados
# 7496 registros procesados
# 7534 registros procesados
# 7572 registros procesados
# 7610 registros procesados
# 7648 registros procesados
# 7686 registros procesados
# 7724 registros procesados
# 7762 registros procesados
# 7800 registros procesados
# 7838 registros procesados
# 7876 registros procesados
# 7914 registros procesados
# 7952 registros procesados
# 7990 registros procesados
# 8028 registros procesados
# 8066 registros procesados
# 8104 registros procesados
# 8142 registros procesados
# 8180 registros procesados
# 8218 registros procesados
# 8256 registros procesados
# 8294 registros procesados
# 8332 registros procesados
# 8370 registros procesados
# 8408 registros procesados
# 8446 registros procesados
# 8484 registros procesados
# 8522 registros procesados
# 8560 registros procesados
# 8598 registros procesados
# 8636 registros procesados
# 8674 registros procesados
# 8712 registros procesados
# 8750 registros procesados
# 8788 registros procesados
# 8826 registros procesados
# 8864 registros procesados
# 8902 registros procesados
# 8940 registros procesados
# 8978 registros procesados
# 9016 registros procesados
# 9054 registros procesados
# 9092 registros procesados
# 9130 registros procesados
# 9168 registros procesados
# 9206 registros procesados
# 9244 registros procesados
# 9282 registros procesados
# 9320 registros procesados
# 9358 registros procesados
# 9396 registros procesados
# 9434 registros procesados
# 9472 registros procesados
# 9510 registros procesados
# 9548 registros procesados
# 9586 registros procesados
# 9624 registros procesados
# 9662 registros procesados
# 9700 registros procesados
# 9738 registros procesados
# 9776 registros procesados
# 9814 registros procesados
# 9852 registros procesados
# 9890 registros procesados
# 9928 registros procesados
# 9966 registros procesados
# 10004 registros procesados
# 10042 registros procesados
# 10080 registros procesados
# 10118 registros procesados
# 10156 registros procesados
# 10194 registros procesados
# 10232 registros procesados
# 10270 registros procesados
# 10308 registros procesados
# 10346 registros procesados
# 10384 registros procesados
# 10422 registros procesados
# 10460 registros procesados
# 10498 registros procesados
# 10536 registros procesados
# 10574 registros procesados
# 10612 registros procesados
# 10650 registros procesados
# 10688 registros procesados
# 10726 registros procesados
# 10764 registros procesados
# 10802 registros procesados
# 10840 registros procesados
# 10878 registros procesados
# 10916 registros procesados
# 10954 registros procesados
# 10992 registros procesados
# 11030 registros procesados
# 11068 registros procesados
# 11106 registros procesados
# 11144 registros procesados
# 11182 registros procesados
# 11220 registros procesados
# 11258 registros procesados
# 11296 registros procesados
# 11334 registros procesados
# 11372 registros procesados
# 11410 registros procesados
# 11448 registros procesados
# 11486 registros procesados
# 11524 registros procesados
# 11562 registros procesados
# 11600 registros procesados
# 11638 registros procesados
# 11676 registros procesados
# 11714 registros procesados
# 11752 registros procesados
# 11790 registros procesados
# 11828 registros procesados
# 11866 registros procesados
# 11904 registros procesados
# 11942 registros procesados
# 11980 registros procesados
# 12018 registros procesados
# 12056 registros procesados
# 12094 registros procesados
# 12132 registros procesados
# 12170 registros procesados
# 12208 registros procesados
# 12246 registros procesados
# 12284 registros procesados
# 12322 registros procesados
# 12360 registros procesados
# 12398 registros procesados
# 12436 registros procesados
# 12474 registros procesados
# 12512 registros procesados
# 12550 registros procesados
# 12588 registros procesados
# 12626 registros procesados
# 12664 registros procesados
# 12702 registros procesados
# 12740 registros procesados
# 12778 registros procesados
# 12816 registros procesados
# 12854 registros procesados
# 12892 registros procesados
# 12930 registros procesados
# 12968 registros procesados
# 13006 registros procesados
# 13044 registros procesados
# 13082 registros procesados
# 13120 registros procesados
# 13158 registros procesados
# 13196 registros procesados
# 13234 registros procesados
# 13272 registros procesados
# 13310 registros procesados
# 13348 registros procesados
# 13386 registros procesados
# 13424 registros procesados
# 13462 registros procesados
# 13500 registros procesados
# 13538 registros procesados
# 13576 registros procesados
# 13614 registros procesados
# 13652 registros procesados
# 13690 registros procesados
# 13728 registros procesados
# 13766 registros procesados
# 13804 registros procesados
# 13842 registros procesados
# 13880 registros procesados
# 13918 registros procesados
# 13956 registros procesados
# 13994 registros procesados
# 14032 registros procesados
# 14070 registros procesados
# 14108 registros procesados
# 14146 registros procesados
# 14184 registros procesados
# 14222 registros procesados
# 14260 registros procesados
# 14298 registros procesados
# 14336 registros procesados
# 14374 registros procesados
# 14412 registros procesados
# 14450 registros procesados
# 14488 registros procesados
# 14526 registros procesados
# 14564 registros procesados
# 14602 registros procesados
# 14640 registros procesados
# 14678 registros procesados
# 14716 registros procesados
# 14754 registros procesados
# 14792 registros procesados
# 14830 registros procesados
# 14868 registros procesados
# 14906 registros procesados
# 14944 registros procesados
# 14982 registros procesados
# 15020 registros procesados
# 15058 registros procesados
# 15096 registros procesados
# 15134 registros procesados
# 15172 registros procesados
# 15210 registros procesados
# 15248 registros procesados
# 15286 registros procesados
# 15324 registros procesados
# 15362 registros procesados
# 15400 registros procesados
# 15438 registros procesados
# 15476 registros procesados
# 15514 registros procesados
# 15552 registros procesados
# 15590 registros procesados
# 15628 registros procesados
# Ubigeo SALAMANCA: No se han contabilizado actas aún. Proyectando resultados...
# 15668 registros procesados
# 15706 registros procesados
# 15744 registros procesados
# 15782 registros procesados
# 15820 registros procesados
# 15858 registros procesados
# 15896 registros procesados
# 15934 registros procesados
# 15972 registros procesados
# 16010 registros procesados
# 16048 registros procesados
# 16086 registros procesados
# 16124 registros procesados
# 16162 registros procesados
# 16200 registros procesados
# 16238 registros procesados
# 16276 registros procesados
# 16314 registros procesados
# 16352 registros procesados
# 16390 registros procesados
# 16428 registros procesados
# 16466 registros procesados
# 16504 registros procesados
# 16542 registros procesados
# 16580 registros procesados
# 16618 registros procesados
# 16656 registros procesados
# 16694 registros procesados
# 16732 registros procesados
# 16770 registros procesados
# 16808 registros procesados
# 16846 registros procesados
# 16884 registros procesados
# 16922 registros procesados
# 16960 registros procesados
# 16998 registros procesados
# 17036 registros procesados
# 17074 registros procesados
# 17112 registros procesados
# 17150 registros procesados
# 17188 registros procesados
# 17226 registros procesados
# 17264 registros procesados
# 17302 registros procesados
# 17340 registros procesados
# 17378 registros procesados
# 17416 registros procesados
# 17454 registros procesados
# 17492 registros procesados
# 17530 registros procesados
# 17568 registros procesados
# 17606 registros procesados
# 17644 registros procesados
# 17682 registros procesados
# 17720 registros procesados
# 17758 registros procesados
# 17796 registros procesados
# 17834 registros procesados
# 17872 registros procesados
# 17910 registros procesados
# 17948 registros procesados
# 17986 registros procesados
# 18024 registros procesados
# 18062 registros procesados
# 18100 registros procesados
# 18138 registros procesados
# 18176 registros procesados
# 18214 registros procesados
# 18252 registros procesados
# 18290 registros procesados
# 18328 registros procesados
# 18366 registros procesados
# 18404 registros procesados
# 18442 registros procesados
# 18480 registros procesados
# 18518 registros procesados
# 18556 registros procesados
# 18594 registros procesados
# 18632 registros procesados
# 18670 registros procesados
# 18708 registros procesados
# 18746 registros procesados
# 18784 registros procesados
# 18822 registros procesados
# 18860 registros procesados
# 18898 registros procesados
# 18936 registros procesados
# 18974 registros procesados
# 19012 registros procesados
# 19050 registros procesados
# 19088 registros procesados
# 19126 registros procesados
# 19164 registros procesados
# 19202 registros procesados
# 19240 registros procesados
# 19278 registros procesados
# 19316 registros procesados
# 19354 registros procesados
# 19392 registros procesados
# 19430 registros procesados
# 19468 registros procesados
# 19506 registros procesados
# 19544 registros procesados
# 19582 registros procesados
# 19620 registros procesados
# 19658 registros procesados
# 19696 registros procesados
# 19734 registros procesados
# 19772 registros procesados
# 19810 registros procesados
# 19848 registros procesados
# 19886 registros procesados
# 19924 registros procesados
# 19962 registros procesados
# 20000 registros procesados
# 20038 registros procesados
# 20076 registros procesados
# 20114 registros procesados
# 20152 registros procesados
# 20190 registros procesados
# 20228 registros procesados
# 20266 registros procesados
# 20304 registros procesados
# 20342 registros procesados
# 20380 registros procesados
# 20418 registros procesados
# 20456 registros procesados
# 20494 registros procesados
# 20532 registros procesados
# 20570 registros procesados
# 20608 registros procesados
# 20646 registros procesados
# 20684 registros procesados
# 20722 registros procesados
# 20760 registros procesados
# 20798 registros procesados
# 20836 registros procesados
# 20874 registros procesados
# 20912 registros procesados
# 20950 registros procesados
# 20988 registros procesados
# 21026 registros procesados
# 21064 registros procesados
# 21102 registros procesados
# 21140 registros procesados
# 21178 registros procesados
# 21216 registros procesados
# 21254 registros procesados
# 21292 registros procesados
# 21330 registros procesados
# 21368 registros procesados
# 21406 registros procesados
# 21444 registros procesados
# 21482 registros procesados
# 21520 registros procesados
# 21558 registros procesados
# 21596 registros procesados
# 21634 registros procesados
# 21672 registros procesados
# 21710 registros procesados
# 21748 registros procesados
# 21786 registros procesados
# 21824 registros procesados
# 21862 registros procesados
# 21900 registros procesados
# 21938 registros procesados
# 21976 registros procesados
# 22014 registros procesados
# 22052 registros procesados
# 22090 registros procesados
# 22128 registros procesados
# 22166 registros procesados
# 22204 registros procesados
# 22242 registros procesados
# 22280 registros procesados
# 22318 registros procesados
# 22356 registros procesados
# 22394 registros procesados
# 22432 registros procesados
# 22470 registros procesados
# 22508 registros procesados
# 22546 registros procesados
# 22584 registros procesados
# 22622 registros procesados
# 22660 registros procesados
# 22698 registros procesados
# 22736 registros procesados
# 22774 registros procesados
# 22812 registros procesados
# 22850 registros procesados
# 22888 registros procesados
# 22926 registros procesados
# 22964 registros procesados
# 23002 registros procesados
# 23040 registros procesados
# 23078 registros procesados
# 23116 registros procesados
# 23154 registros procesados
# 23192 registros procesados
# 23230 registros procesados
# 23268 registros procesados
# 23306 registros procesados
# 23344 registros procesados
# 23382 registros procesados
# 23420 registros procesados
# 23458 registros procesados
# 23496 registros procesados
# 23534 registros procesados
# 23572 registros procesados
# 23610 registros procesados
# 23648 registros procesados
# 23686 registros procesados
# 23724 registros procesados
# 23762 registros procesados
# 23800 registros procesados
# 23838 registros procesados
# 23876 registros procesados
# 23914 registros procesados
# 23952 registros procesados
# 23990 registros procesados
# 24028 registros procesados
# 24066 registros procesados
# 24104 registros procesados
# 24142 registros procesados
# 24180 registros procesados
# 24218 registros procesados
# 24256 registros procesados
# 24294 registros procesados
# 24332 registros procesados
# 24370 registros procesados
# 24408 registros procesados
# 24446 registros procesados
# 24484 registros procesados
# 24522 registros procesados
# 24560 registros procesados
# 24598 registros procesados
# 24636 registros procesados
# 24674 registros procesados
# 24712 registros procesados
# 24750 registros procesados
# 24788 registros procesados
# 24826 registros procesados
# 24864 registros procesados
# 24902 registros procesados
# 24940 registros procesados
# 24978 registros procesados
# 25016 registros procesados
# 25054 registros procesados
# 25092 registros procesados
# 25130 registros procesados
# 25168 registros procesados
# 25206 registros procesados
# 25244 registros procesados
# 25282 registros procesados
# 25320 registros procesados
# 25358 registros procesados
# 25396 registros procesados
# 25434 registros procesados
# 25472 registros procesados
# 25510 registros procesados
# 25548 registros procesados
# 25586 registros procesados
# 25624 registros procesados
# 25662 registros procesados
# 25700 registros procesados
# 25738 registros procesados
# 25776 registros procesados
# 25814 registros procesados
# 25852 registros procesados
# 25890 registros procesados
# 25928 registros procesados
# 25966 registros procesados
# 26004 registros procesados
# 26042 registros procesados
# 26080 registros procesados
# 26118 registros procesados
# 26156 registros procesados
# 26194 registros procesados
# 26232 registros procesados
# 26270 registros procesados
# 26308 registros procesados
# 26346 registros procesados
# 26384 registros procesados
# 26422 registros procesados
# 26460 registros procesados
# 26498 registros procesados
# 26536 registros procesados
# 26574 registros procesados
# 26612 registros procesados
# 26650 registros procesados
# 26688 registros procesados
# 26726 registros procesados
# 26764 registros procesados
# 26802 registros procesados
# 26840 registros procesados
# 26878 registros procesados
# 26916 registros procesados
# 26954 registros procesados
# 26992 registros procesados
# 27030 registros procesados
# 27068 registros procesados
# 27106 registros procesados
# 27144 registros procesados
# 27182 registros procesados
# 27220 registros procesados
# 27258 registros procesados
# 27296 registros procesados
# 27334 registros procesados
# 27372 registros procesados
# 27410 registros procesados
# 27448 registros procesados
# Ubigeo CIELO_PUNCO: No se han contabilizado actas aún. Proyectando resultados...
# 27488 registros procesados
# 27526 registros procesados
# 27564 registros procesados
# Ubigeo KIMBIRI: No se han contabilizado actas aún. Proyectando resultados...
# 27604 registros procesados
# Ubigeo MANITEA: No se han contabilizado actas aún. Proyectando resultados...
# 27644 registros procesados
# Ubigeo MEGANTONI: No se han contabilizado actas aún. Proyectando resultados...
# Ubigeo PICHARI: No se han contabilizado actas aún. Proyectando resultados...
# 27686 registros procesados
# 27724 registros procesados
# 27762 registros procesados
# Ubigeo UNION_ASHANINKA: No se han contabilizado actas aún. Proyectando resultados...
# Ubigeo VILLA_KINTIARINA: No se han contabilizado actas aún. Proyectando resultados...
# Ubigeo VILLA_VIRGEN: No se han contabilizado actas aún. Proyectando resultados...
# 27806 registros procesados
# 27844 registros procesados
# 27882 registros procesados
# 27920 registros procesados
# 27958 registros procesados
# 27996 registros procesados
# 28034 registros procesados
# 28072 registros procesados
# 28110 registros procesados
# 28148 registros procesados
# 28186 registros procesados
# 28224 registros procesados
# 28262 registros procesados
# 28300 registros procesados
# 28338 registros procesados
# 28376 registros procesados
# 28414 registros procesados
# 28452 registros procesados
# 28490 registros procesados
# 28528 registros procesados
# 28566 registros procesados
# 28604 registros procesados
# 28642 registros procesados
# 28680 registros procesados
# 28718 registros procesados
# 28756 registros procesados
# 28794 registros procesados
# 28832 registros procesados
# 28870 registros procesados
# 28908 registros procesados
# 28946 registros procesados
# 28984 registros procesados
# Ubigeo MARCAS: No se han contabilizado actas aún. Proyectando resultados...
# 29024 registros procesados
# 29062 registros procesados
# 29100 registros procesados
# 29138 registros procesados
# 29176 registros procesados
# 29214 registros procesados
# 29252 registros procesados
# 29290 registros procesados
# 29328 registros procesados
# 29366 registros procesados
# 29404 registros procesados
# 29442 registros procesados
# 29480 registros procesados
# 29518 registros procesados
# 29556 registros procesados
# 29594 registros procesados
# 29632 registros procesados
# 29670 registros procesados
# 29708 registros procesados
# 29746 registros procesados
# 29784 registros procesados
# 29822 registros procesados
# 29860 registros procesados
# 29898 registros procesados
# 29936 registros procesados
# 29974 registros procesados
# 30012 registros procesados
# 30050 registros procesados
# 30088 registros procesados
# 30126 registros procesados
# 30164 registros procesados
# 30202 registros procesados
# 30240 registros procesados
# 30278 registros procesados
# 30316 registros procesados
# 30354 registros procesados
# 30392 registros procesados
# 30430 registros procesados
# 30468 registros procesados
# 30506 registros procesados
# 30544 registros procesados
# 30582 registros procesados
# 30620 registros procesados
# 30658 registros procesados
# 30696 registros procesados
# 30734 registros procesados
# 30772 registros procesados
# 30810 registros procesados
# 30848 registros procesados
# 30886 registros procesados
# 30924 registros procesados
# 30962 registros procesados
# 31000 registros procesados
# 31038 registros procesados
# 31076 registros procesados
# 31114 registros procesados
# 31152 registros procesados
# 31190 registros procesados
# 31228 registros procesados
# 31266 registros procesados
# 31304 registros procesados
# 31342 registros procesados
# 31380 registros procesados
# 31418 registros procesados
# 31456 registros procesados
# 31494 registros procesados
# 31532 registros procesados
# 31570 registros procesados
# 31608 registros procesados
# 31646 registros procesados
# 31684 registros procesados
# 31722 registros procesados
# 31760 registros procesados
# 31798 registros procesados
# 31836 registros procesados
# 31874 registros procesados
# 31912 registros procesados
# 31950 registros procesados
# 31988 registros procesados
# 32026 registros procesados
# 32064 registros procesados
# 32102 registros procesados
# 32140 registros procesados
# 32178 registros procesados
# 32216 registros procesados
# 32254 registros procesados
# 32292 registros procesados
# 32330 registros procesados
# 32368 registros procesados
# 32406 registros procesados
# 32444 registros procesados
# 32482 registros procesados
# 32520 registros procesados
# 32558 registros procesados
# 32596 registros procesados
# 32634 registros procesados
# 32672 registros procesados
# 32710 registros procesados
# 32748 registros procesados
# 32786 registros procesados
# 32824 registros procesados
# 32862 registros procesados
# 32900 registros procesados
# 32938 registros procesados
# 32976 registros procesados
# 33014 registros procesados
# 33052 registros procesados
# 33090 registros procesados
# 33128 registros procesados
# 33166 registros procesados
# 33204 registros procesados
# 33242 registros procesados
# 33280 registros procesados
# 33318 registros procesados
# 33356 registros procesados
# 33394 registros procesados
# 33432 registros procesados
# 33470 registros procesados
# 33508 registros procesados
# 33546 registros procesados
# 33584 registros procesados
# 33622 registros procesados
# 33660 registros procesados
# 33698 registros procesados
# 33736 registros procesados
# 33774 registros procesados
# 33812 registros procesados
# 33850 registros procesados
# 33888 registros procesados
# 33926 registros procesados
# 33964 registros procesados
# 34002 registros procesados
# 34040 registros procesados
# 34078 registros procesados
# 34116 registros procesados
# 34154 registros procesados
# 34192 registros procesados
# 34230 registros procesados
# 34268 registros procesados
# 34306 registros procesados
# 34344 registros procesados
# 34382 registros procesados
# 34420 registros procesados
# 34458 registros procesados
# 34496 registros procesados
# 34534 registros procesados
# 34572 registros procesados
# 34610 registros procesados
# 34648 registros procesados
# 34686 registros procesados
# 34724 registros procesados
# 34762 registros procesados
# 34800 registros procesados
# 34838 registros procesados
# 34876 registros procesados
# 34914 registros procesados
# 34952 registros procesados
# 34990 registros procesados
# 35028 registros procesados
# 35066 registros procesados
# 35104 registros procesados
# 35142 registros procesados
# 35180 registros procesados
# 35218 registros procesados
# 35256 registros procesados
# 35294 registros procesados
# 35332 registros procesados
# 35370 registros procesados
# 35408 registros procesados
# 35446 registros procesados
# 35484 registros procesados
# 35522 registros procesados
# 35560 registros procesados
# 35598 registros procesados
# 35636 registros procesados
# 35674 registros procesados
# 35712 registros procesados
# 35750 registros procesados
# 35788 registros procesados
# 35826 registros procesados
# 35864 registros procesados
# 35902 registros procesados
# 35940 registros procesados
# 35978 registros procesados
# 36016 registros procesados
# 36054 registros procesados
# 36092 registros procesados
# 36130 registros procesados
# 36168 registros procesados
# 36206 registros procesados
# 36244 registros procesados
# 36282 registros procesados
# Ubigeo TIBILLO: No se han contabilizado actas aún. Proyectando resultados...
# 36322 registros procesados
# 36360 registros procesados
# 36398 registros procesados
# 36436 registros procesados
# 36474 registros procesados
# 36512 registros procesados
# 36550 registros procesados
# 36588 registros procesados
# 36626 registros procesados
# 36664 registros procesados
# 36702 registros procesados
# 36740 registros procesados
# 36778 registros procesados
# 36816 registros procesados
# 36854 registros procesados
# 36892 registros procesados
# 36930 registros procesados
# 36968 registros procesados
# 37006 registros procesados
# 37044 registros procesados
# 37082 registros procesados
# 37120 registros procesados
# 37158 registros procesados
# 37196 registros procesados
# 37234 registros procesados
# 37272 registros procesados
# 37310 registros procesados
# 37348 registros procesados
# 37386 registros procesados
# 37424 registros procesados
# 37462 registros procesados
# 37500 registros procesados
# 37538 registros procesados
# 37576 registros procesados
# 37614 registros procesados
# 37652 registros procesados
# 37690 registros procesados
# 37728 registros procesados
# 37766 registros procesados
# 37804 registros procesados
# 37842 registros procesados
# 37880 registros procesados
# 37918 registros procesados
# 37956 registros procesados
# 37994 registros procesados
# 38032 registros procesados
# 38070 registros procesados
# 38108 registros procesados
# 38146 registros procesados
# 38184 registros procesados
# 38222 registros procesados
# 38260 registros procesados
# 38298 registros procesados
# 38336 registros procesados
# 38374 registros procesados
# 38412 registros procesados
# 38450 registros procesados
# 38488 registros procesados
# 38526 registros procesados
# 38564 registros procesados
# 38602 registros procesados
# 38640 registros procesados
# 38678 registros procesados
# 38716 registros procesados
# 38754 registros procesados
# 38792 registros procesados
# 38830 registros procesados
# 38868 registros procesados
# 38906 registros procesados
# 38944 registros procesados
# 38982 registros procesados
# 39020 registros procesados
# 39058 registros procesados
# 39096 registros procesados
# 39134 registros procesados
# 39172 registros procesados
# 39210 registros procesados
# 39248 registros procesados
# 39286 registros procesados
# 39324 registros procesados
# 39362 registros procesados
# 39400 registros procesados
# 39438 registros procesados
# 39476 registros procesados
# 39514 registros procesados
# 39552 registros procesados
# 39590 registros procesados
# 39628 registros procesados
# 39666 registros procesados
# 39704 registros procesados
# 39742 registros procesados
# 39780 registros procesados
# 39818 registros procesados
# 39856 registros procesados
# 39894 registros procesados
# 39932 registros procesados
# 39970 registros procesados
# 40008 registros procesados
# 40046 registros procesados
# 40084 registros procesados
# 40122 registros procesados
# 40160 registros procesados
# 40198 registros procesados
# 40236 registros procesados
# 40274 registros procesados
# 40312 registros procesados
# 40350 registros procesados
# 40388 registros procesados
# 40426 registros procesados
# 40464 registros procesados
# 40502 registros procesados
# 40540 registros procesados
# 40578 registros procesados
# 40616 registros procesados
# 40654 registros procesados
# 40692 registros procesados
# 40730 registros procesados
# 40768 registros procesados
# 40806 registros procesados
# 40844 registros procesados
# 40882 registros procesados
# 40920 registros procesados
# 40958 registros procesados
# 40996 registros procesados
# 41034 registros procesados
# 41072 registros procesados
# 41110 registros procesados
# 41148 registros procesados
# 41186 registros procesados
# 41224 registros procesados
# 41262 registros procesados
# 41300 registros procesados
# 41338 registros procesados
# 41376 registros procesados
# 41414 registros procesados
# 41452 registros procesados
# 41490 registros procesados
# 41528 registros procesados
# 41566 registros procesados
# 41604 registros procesados
# 41642 registros procesados
# 41680 registros procesados
# 41718 registros procesados
# 41756 registros procesados
# 41794 registros procesados
# 41832 registros procesados
# 41870 registros procesados
# 41908 registros procesados
# 41946 registros procesados
# 41984 registros procesados
# Ubigeo SAN_JOSE: No se han contabilizado actas aún. Proyectando resultados...
# Ubigeo COSTA_RICA: No se han contabilizado actas aún en el nivel2. Proyectando resultados...
# 42024 registros procesados
# 42062 registros procesados
# 42100 registros procesados
# 42138 registros procesados
# 42176 registros procesados
# 42214 registros procesados
# 42252 registros procesados
# 42290 registros procesados
# 42328 registros procesados
# 42366 registros procesados
# 42404 registros procesados
# 42442 registros procesados
# 42480 registros procesados
# 42518 registros procesados
# 42556 registros procesados
# 42594 registros procesados
# 42632 registros procesados
# 42670 registros procesados
# 42708 registros procesados
# 42746 registros procesados
# 42784 registros procesados
# 42822 registros procesados
# 42860 registros procesados
# 42898 registros procesados
# 42936 registros procesados
# 42974 registros procesados
# 43012 registros procesados
# 43050 registros procesados
# 43088 registros procesados
# 43126 registros procesados
# 43164 registros procesados
# 43202 registros procesados
# 43240 registros procesados
# 43278 registros procesados
# 43316 registros procesados
# 43354 registros procesados
# 43392 registros procesados
# 43430 registros procesados
# 43468 registros procesados
# 43506 registros procesados
# 43544 registros procesados
# 43582 registros procesados
# 43620 registros procesados
# 43658 registros procesados
# 43696 registros procesados
# 43734 registros procesados
# 43772 registros procesados
# 43810 registros procesados
# 43848 registros procesados
# 43886 registros procesados
# 43924 registros procesados
# 43962 registros procesados
# 44000 registros procesados
# 44038 registros procesados
# 44076 registros procesados
# 44114 registros procesados
# 44152 registros procesados
# 44190 registros procesados
# 44228 registros procesados
# 44266 registros procesados
# 44304 registros procesados
# 44342 registros procesados
# 44380 registros procesados
# 44418 registros procesados
# 44456 registros procesados
# 44494 registros procesados
# 44532 registros procesados
# 44570 registros procesados
# 44608 registros procesados
# 44646 registros procesados
# 44684 registros procesados
# 44722 registros procesados
# 44760 registros procesados
# 44798 registros procesados
# 44836 registros procesados
# 44874 registros procesados
# 44912 registros procesados
# 44950 registros procesados
# 44988 registros procesados
# 45026 registros procesados
# 45064 registros procesados
# 45102 registros procesados
# 45140 registros procesados
# 45178 registros procesados
# 45216 registros procesados
# 45254 registros procesados
# 45292 registros procesados
# 45330 registros procesados
# 45368 registros procesados
# 45406 registros procesados
# 45444 registros procesados
# 45482 registros procesados
# 45520 registros procesados
# 45558 registros procesados
# 45596 registros procesados
# 45634 registros procesados
# 45672 registros procesados
# 45710 registros procesados
# 45748 registros procesados
# 45786 registros procesados
# 45824 registros procesados
# 45862 registros procesados
# 45900 registros procesados
# 45938 registros procesados
# 45976 registros procesados
# 46014 registros procesados
# 46052 registros procesados
# 46090 registros procesados
# 46128 registros procesados
# 46166 registros procesados
# 46204 registros procesados
# 46242 registros procesados
# 46280 registros procesados
# 46318 registros procesados
# 46356 registros procesados
# 46394 registros procesados
# 46432 registros procesados
# 46470 registros procesados
# 46508 registros procesados
# 46546 registros procesados
# 46584 registros procesados
# 46622 registros procesados
# 46660 registros procesados
# 46698 registros procesados
# 46736 registros procesados
# 46774 registros procesados
# 46812 registros procesados
# 46850 registros procesados
# 46888 registros procesados
# 46926 registros procesados
# 46964 registros procesados
# 47002 registros procesados
# 47040 registros procesados
# 47078 registros procesados
# 47116 registros procesados
# 47154 registros procesados
# 47192 registros procesados
# 47230 registros procesados
# 47268 registros procesados
# 47306 registros procesados
# 47344 registros procesados
# 47382 registros procesados
# 47420 registros procesados
# 47458 registros procesados
# 47496 registros procesados
# 47534 registros procesados
# 47572 registros procesados
# 47610 registros procesados
# 47648 registros procesados
# 47686 registros procesados
# 47724 registros procesados
# 47762 registros procesados
# 47800 registros procesados
# 47838 registros procesados
# 47876 registros procesados
# 47914 registros procesados
# 47952 registros procesados
# 47990 registros procesados
# 48028 registros procesados
# 48066 registros procesados
# 48104 registros procesados
# 48142 registros procesados
# 48180 registros procesados
# 48218 registros procesados
# 48256 registros procesados
# 48294 registros procesados
# 48332 registros procesados
# 48370 registros procesados
# 48408 registros procesados
# 48446 registros procesados
# 48484 registros procesados
# 48522 registros procesados
# 48560 registros procesados
# 48598 registros procesados
# 48636 registros procesados
# 48674 registros procesados
# 48712 registros procesados
# 48750 registros procesados
# 48788 registros procesados
# 48826 registros procesados
# 48864 registros procesados
# 48902 registros procesados
# 48940 registros procesados
# 48978 registros procesados
# 49016 registros procesados
# 49054 registros procesados
# Ubigeo SANTA_MARIA_DEL_MAR: No se han contabilizado actas aún. Proyectando resultados...
# 49094 registros procesados
# 49132 registros procesados
# 49170 registros procesados
# 49208 registros procesados
# 49246 registros procesados
# 49284 registros procesados
# 49322 registros procesados
# 49360 registros procesados
# 49398 registros procesados
# 49436 registros procesados
# 49474 registros procesados
# 49512 registros procesados
# 49550 registros procesados
# 49588 registros procesados
# 49626 registros procesados
# 49664 registros procesados
# 49702 registros procesados
# 49740 registros procesados
# 49778 registros procesados
# 49816 registros procesados
# 49854 registros procesados
# 49892 registros procesados
# 49930 registros procesados
# 49968 registros procesados
# 50006 registros procesados
# 50044 registros procesados
# 50082 registros procesados
# 50120 registros procesados
# 50158 registros procesados
# 50196 registros procesados
# 50234 registros procesados
# 50272 registros procesados
# 50310 registros procesados
# 50348 registros procesados
# 50386 registros procesados
# 50424 registros procesados
# 50462 registros procesados
# 50500 registros procesados
# 50538 registros procesados
# 50576 registros procesados
# 50614 registros procesados
# 50652 registros procesados
# 50690 registros procesados
# 50728 registros procesados
# Ubigeo ANDOAS: No se han contabilizado actas aún. Proyectando resultados...
# Ubigeo CAHUAPANAS: No se han contabilizado actas aún. Proyectando resultados...
# 50770 registros procesados
# Ubigeo MORONA: No se han contabilizado actas aún. Proyectando resultados...
# 50810 registros procesados
# 50848 registros procesados
# 50886 registros procesados
# 50924 registros procesados
# 50962 registros procesados
# 51000 registros procesados
# 51038 registros procesados
# 51076 registros procesados
# 51114 registros procesados
# 51152 registros procesados
# 51190 registros procesados
# 51228 registros procesados
# 51266 registros procesados
# 51304 registros procesados
# 51342 registros procesados
# 51380 registros procesados
# 51418 registros procesados
# 51456 registros procesados
# 51494 registros procesados
# 51532 registros procesados
# 51570 registros procesados
# 51608 registros procesados
# 51646 registros procesados
# 51684 registros procesados
# 51722 registros procesados
# 51760 registros procesados
# 51798 registros procesados
# 51836 registros procesados
# 51874 registros procesados
# 51912 registros procesados
# 51950 registros procesados
# 51988 registros procesados
# 52026 registros procesados
# Ubigeo YAQUERANA: No se han contabilizado actas aún. Proyectando resultados...
# 52066 registros procesados
# 52104 registros procesados
# 52142 registros procesados
# 52180 registros procesados
# 52218 registros procesados
# 52256 registros procesados
# 52294 registros procesados
# 52332 registros procesados
# 52370 registros procesados
# 52408 registros procesados
# 52446 registros procesados
# 52484 registros procesados
# 52522 registros procesados
# 52560 registros procesados
# 52598 registros procesados
# 52636 registros procesados
# 52674 registros procesados
# 52712 registros procesados
# 52750 registros procesados
# 52788 registros procesados
# 52826 registros procesados
# 52864 registros procesados
# 52902 registros procesados
# 52940 registros procesados
# 52978 registros procesados
# 53016 registros procesados
# 53054 registros procesados
# 53092 registros procesados
# 53130 registros procesados
# 53168 registros procesados
# 53206 registros procesados
# 53244 registros procesados
# 53282 registros procesados
# 53320 registros procesados
# 53358 registros procesados
# 53396 registros procesados
# 53434 registros procesados
# 53472 registros procesados
# 53510 registros procesados
# 53548 registros procesados
# 53586 registros procesados
# 53624 registros procesados
# 53662 registros procesados
# 53700 registros procesados
# 53738 registros procesados
# 53776 registros procesados
# 53814 registros procesados
# 53852 registros procesados
# 53890 registros procesados
# 53928 registros procesados
# 53966 registros procesados
# 54004 registros procesados
# 54042 registros procesados
# 54080 registros procesados
# 54118 registros procesados
# 54156 registros procesados
# 54194 registros procesados
# 54232 registros procesados
# 54270 registros procesados
# 54308 registros procesados
# 54346 registros procesados
# 54384 registros procesados
# 54422 registros procesados
# 54460 registros procesados
# 54498 registros procesados
# 54536 registros procesados
# 54574 registros procesados
# 54612 registros procesados
# 54650 registros procesados
# 54688 registros procesados
# 54726 registros procesados
# 54764 registros procesados
# 54802 registros procesados
# 54840 registros procesados
# 54878 registros procesados
# 54916 registros procesados
# 54954 registros procesados
# 54992 registros procesados
# 55030 registros procesados
# 55068 registros procesados
# 55106 registros procesados
# 55144 registros procesados
# 55182 registros procesados
# 55220 registros procesados
# 55258 registros procesados
# 55296 registros procesados
# 55334 registros procesados
# 55372 registros procesados
# 55410 registros procesados
# 55448 registros procesados
# 55486 registros procesados
# 55524 registros procesados
# 55562 registros procesados
# 55600 registros procesados
# 55638 registros procesados
# 55676 registros procesados
# 55714 registros procesados
# 55752 registros procesados
# 55790 registros procesados
# 55828 registros procesados
# 55866 registros procesados
# 55904 registros procesados
# 55942 registros procesados
# 55980 registros procesados
# 56018 registros procesados
# 56056 registros procesados
# 56094 registros procesados
# 56132 registros procesados
# 56170 registros procesados
# 56208 registros procesados
# 56246 registros procesados
# 56284 registros procesados
# 56322 registros procesados
# 56360 registros procesados
# 56398 registros procesados
# 56436 registros procesados
# 56474 registros procesados
# 56512 registros procesados
# 56550 registros procesados
# 56588 registros procesados
# 56626 registros procesados
# 56664 registros procesados
# 56702 registros procesados
# 56740 registros procesados
# 56778 registros procesados
# 56816 registros procesados
# 56854 registros procesados
# 56892 registros procesados
# 56930 registros procesados
# 56968 registros procesados
# 57006 registros procesados
# 57044 registros procesados
# 57082 registros procesados
# 57120 registros procesados
# 57158 registros procesados
# 57196 registros procesados
# 57234 registros procesados
# 57272 registros procesados
# 57310 registros procesados
# 57348 registros procesados
# 57386 registros procesados
# 57424 registros procesados
# 57462 registros procesados
# 57500 registros procesados
# 57538 registros procesados
# 57576 registros procesados
# 57614 registros procesados
# 57652 registros procesados
# 57690 registros procesados
# 57728 registros procesados
# 57766 registros procesados
# 57804 registros procesados
# 57842 registros procesados
# 57880 registros procesados
# 57918 registros procesados
# 57956 registros procesados
# 57994 registros procesados
# 58032 registros procesados
# 58070 registros procesados
# 58108 registros procesados
# 58146 registros procesados
# 58184 registros procesados
# 58222 registros procesados
# 58260 registros procesados
# 58298 registros procesados
# 58336 registros procesados
# 58374 registros procesados
# 58412 registros procesados
# 58450 registros procesados
# 58488 registros procesados
# 58526 registros procesados
# 58564 registros procesados
# 58602 registros procesados
# 58640 registros procesados
# 58678 registros procesados
# 58716 registros procesados
# 58754 registros procesados
# 58792 registros procesados
# 58830 registros procesados
# 58868 registros procesados
# 58906 registros procesados
# 58944 registros procesados
# 58982 registros procesados
# 59020 registros procesados
# 59058 registros procesados
# 59096 registros procesados
# 59134 registros procesados
# 59172 registros procesados
# 59210 registros procesados
# 59248 registros procesados
# 59286 registros procesados
# 59324 registros procesados
# 59362 registros procesados
# 59400 registros procesados
# 59438 registros procesados
# 59476 registros procesados
# 59514 registros procesados
# 59552 registros procesados
# 59590 registros procesados
# 59628 registros procesados
# 59666 registros procesados
# 59704 registros procesados
# 59742 registros procesados
# 59780 registros procesados
# 59818 registros procesados
# 59856 registros procesados
# 59894 registros procesados
# 59932 registros procesados
# 59970 registros procesados
# 60008 registros procesados
# 60046 registros procesados
# 60084 registros procesados
# 60122 registros procesados
# 60160 registros procesados
# 60198 registros procesados
# 60236 registros procesados
# 60274 registros procesados
# 60312 registros procesados
# 60350 registros procesados
# 60388 registros procesados
# 60426 registros procesados
# 60464 registros procesados
# 60502 registros procesados
# 60540 registros procesados
# 60578 registros procesados
# 60616 registros procesados
# 60654 registros procesados
# 60692 registros procesados
# 60730 registros procesados
# 60768 registros procesados
# 60806 registros procesados
# 60844 registros procesados
# 60882 registros procesados
# 60920 registros procesados
# 60958 registros procesados
# 60996 registros procesados
# 61034 registros procesados
# 61072 registros procesados
# 61110 registros procesados
# 61148 registros procesados
# 61186 registros procesados
# 61224 registros procesados
# 61262 registros procesados
# 61300 registros procesados
# 61338 registros procesados
# 61376 registros procesados
# 61414 registros procesados
# 61452 registros procesados
# 61490 registros procesados
# 61528 registros procesados
# 61566 registros procesados
# 61604 registros procesados
# 61642 registros procesados
# 61680 registros procesados
# 61718 registros procesados
# 61756 registros procesados
# 61794 registros procesados
# 61832 registros procesados
# 61870 registros procesados
# 61908 registros procesados
# 61946 registros procesados
# 61984 registros procesados
# 62022 registros procesados
# 62060 registros procesados
# 62098 registros procesados
# 62136 registros procesados
# 62174 registros procesados
# 62212 registros procesados
# 62250 registros procesados
# 62288 registros procesados
# 62326 registros procesados
# 62364 registros procesados
# 62402 registros procesados
# 62440 registros procesados
# 62478 registros procesados
# 62516 registros procesados
# 62554 registros procesados
# 62592 registros procesados
# 62630 registros procesados
# 62668 registros procesados
# 62706 registros procesados
# 62744 registros procesados
# 62782 registros procesados
# 62820 registros procesados
# 62858 registros procesados
# 62896 registros procesados
# 62934 registros procesados
# 62972 registros procesados
# 63010 registros procesados
# 63048 registros procesados
# 63086 registros procesados
# 63124 registros procesados
# 63162 registros procesados
# 63200 registros procesados
# 63238 registros procesados
# 63276 registros procesados
# 63314 registros procesados
# 63352 registros procesados
# 63390 registros procesados
# 63428 registros procesados
# 63466 registros procesados
# 63504 registros procesados
# 63542 registros procesados
# 63580 registros procesados
# 63618 registros procesados
# 63656 registros procesados
# 63694 registros procesados
# 63732 registros procesados
# 63770 registros procesados
# 63808 registros procesados
# 63846 registros procesados
# 63884 registros procesados
# 63922 registros procesados
# 63960 registros procesados
# 63998 registros procesados
# 64036 registros procesados
# 64074 registros procesados
# 64112 registros procesados
# 64150 registros procesados
# 64188 registros procesados
# 64226 registros procesados
# 64264 registros procesados
# 64302 registros procesados
# 64340 registros procesados
# 64378 registros procesados
# 64416 registros procesados
# 64454 registros procesados
# 64492 registros procesados
# 64530 registros procesados
# 64568 registros procesados
# 64606 registros procesados
# 64644 registros procesados
# 64682 registros procesados
# 64720 registros procesados
# 64758 registros procesados
# 64796 registros procesados
# 64834 registros procesados
# 64872 registros procesados
# 64910 registros procesados
# 64948 registros procesados
# 64986 registros procesados
# 65024 registros procesados
# 65062 registros procesados
# 65100 registros procesados
# 65138 registros procesados
# 65176 registros procesados
# 65214 registros procesados
# Ubigeo ACRA: No se han contabilizado actas aún. Proyectando resultados...
# Ubigeo GHANA: No se han contabilizado actas aún en el nivel2. Proyectando resultados...
# 65254 registros procesados
# Ubigeo RABAT: No se han contabilizado actas aún. Proyectando resultados...
# Ubigeo MARRUECOS: No se han contabilizado actas aún en el nivel2. Proyectando resultados...
# 65294 registros procesados
# 65332 registros procesados
# 65370 registros procesados
# Ubigeo CATAMARCA: No se han contabilizado actas aún. Proyectando resultados...
# 65410 registros procesados
# Ubigeo CORRIENTES: No se han contabilizado actas aún. Proyectando resultados...
# 65450 registros procesados
# 65488 registros procesados
# 65526 registros procesados
# 65564 registros procesados
# Ubigeo SALTA: No se han contabilizado actas aún. Proyectando resultados...
# 65604 registros procesados
# Ubigeo BELO_HORIZONTE: No se han contabilizado actas aún. Proyectando resultados...
# 65644 registros procesados
# 65682 registros procesados
# 65720 registros procesados
# Ubigeo GOIANIA: No se han contabilizado actas aún. Proyectando resultados...
# 65760 registros procesados
# 65798 registros procesados
# 65836 registros procesados
# 65874 registros procesados
# Ubigeo SALVADOR: No se han contabilizado actas aún. Proyectando resultados...
# 65914 registros procesados
# 65952 registros procesados
# 65990 registros procesados
# 66028 registros procesados
# 66066 registros procesados
# 66104 registros procesados
# 66142 registros procesados
# 66180 registros procesados
# 66218 registros procesados
# Ubigeo COPIAPO: No se han contabilizado actas aún. Proyectando resultados...
# 66258 registros procesados
# 66296 registros procesados
# 66334 registros procesados
# 66372 registros procesados
# 66410 registros procesados
# 66448 registros procesados
# 66486 registros procesados
# 66524 registros procesados
# 66562 registros procesados
# 66600 registros procesados
# 66638 registros procesados
# 66676 registros procesados
# 66714 registros procesados
# Ubigeo LOJA: No se han contabilizado actas aún. Proyectando resultados...
# 66754 registros procesados
# 66792 registros procesados
# 66830 registros procesados
# 66868 registros procesados
# 66906 registros procesados
# 66944 registros procesados
# 66982 registros procesados
# 67020 registros procesados
# 67058 registros procesados
# 67096 registros procesados
# 67134 registros procesados
# 67172 registros procesados
# 67210 registros procesados
# 67248 registros procesados
# 67286 registros procesados
# 67324 registros procesados
# 67362 registros procesados
# 67400 registros procesados
# 67438 registros procesados
# Ubigeo SAN_DIEGO: No se han contabilizado actas aún. Proyectando resultados...
# 67478 registros procesados
# 67516 registros procesados
# 67554 registros procesados
# 67592 registros procesados
# 67630 registros procesados
# 67668 registros procesados
# 67706 registros procesados
# 67744 registros procesados
# 67782 registros procesados
# 67820 registros procesados
# 67858 registros procesados
# 67896 registros procesados
# 67934 registros procesados
# Ubigeo SANTIAGO_DE_LOS_CABALLEROS: No se han contabilizado actas aún. Proyectando resultados...
# 67974 registros procesados
# Ubigeo CARACAS: No se han contabilizado actas aún. Proyectando resultados...
# Ubigeo VENEZUELA: No se han contabilizado actas aún en el nivel2. Proyectando resultados...
# Ubigeo RIAD: No se han contabilizado actas aún. Proyectando resultados...
# Ubigeo ARABIA_SAUDITA: No se han contabilizado actas aún en el nivel2. Proyectando resultados...
# Ubigeo DOHA: No se han contabilizado actas aún. Proyectando resultados...
# Ubigeo CATAR: No se han contabilizado actas aún en el nivel2. Proyectando resultados...
# Ubigeo ABU_DABI: No se han contabilizado actas aún. Proyectando resultados...
# Ubigeo EMIRATOS_ARABES_UNIDOS: No se han contabilizado actas aún en el nivel2. Proyectando resultados...
# Ubigeo DUBAI: No se han contabilizado actas aún. Proyectando resultados...
# Ubigeo EMIRATOS_ARABES_UNIDOS: No se han contabilizado actas aún en el nivel2. Proyectando resultados...
# 68022 registros procesados
# 68060 registros procesados
# 68098 registros procesados
# Ubigeo TEHERAN: No se han contabilizado actas aún. Proyectando resultados...
# Ubigeo IRAN: No se han contabilizado actas aún en el nivel2. Proyectando resultados...
# Ubigeo RAMLA: No se han contabilizado actas aún. Proyectando resultados...
# Ubigeo ISRAEL: No se han contabilizado actas aún en el nivel2. Proyectando resultados...
# Ubigeo TEL_AVIV: No se han contabilizado actas aún. Proyectando resultados...
# Ubigeo ISRAEL: No se han contabilizado actas aún en el nivel2. Proyectando resultados...
# 68142 registros procesados
# 68180 registros procesados
# 68218 registros procesados
# 68256 registros procesados
# 68294 registros procesados
# 68332 registros procesados
# 68370 registros procesados
# Ubigeo SAITAMA: No se han contabilizado actas aún. Proyectando resultados...
# 68410 registros procesados
# 68448 registros procesados
# Ubigeo TOKIO: No se han contabilizado actas aún. Proyectando resultados...
# Ubigeo AMMAN: No se han contabilizado actas aún. Proyectando resultados...
# Ubigeo JORDANIA: No se han contabilizado actas aún en el nivel2. Proyectando resultados...
# Ubigeo AL___KUWAIT: No se han contabilizado actas aún. Proyectando resultados...
# Ubigeo KUWAIT: No se han contabilizado actas aún en el nivel2. Proyectando resultados...
# Ubigeo BEIRUT: No se han contabilizado actas aún. Proyectando resultados...
# Ubigeo LIBANO: No se han contabilizado actas aún en el nivel2. Proyectando resultados...
# 68494 registros procesados
# 68532 registros procesados
# 68570 registros procesados
# 68608 registros procesados
# 68646 registros procesados
# 68684 registros procesados
# 68722 registros procesados
# 68760 registros procesados
# 68798 registros procesados
# 68836 registros procesados
# 68874 registros procesados
# 68912 registros procesados
# 68950 registros procesados
# 68988 registros procesados
# 69026 registros procesados
# 69064 registros procesados
# 69102 registros procesados
# 69140 registros procesados
# 69178 registros procesados
# 69216 registros procesados
# Ubigeo MINSK: No se han contabilizado actas aún. Proyectando resultados...
# Ubigeo BIELORRUSIA: No se han contabilizado actas aún en el nivel2. Proyectando resultados...
# 69256 registros procesados
# 69294 registros procesados
# 69332 registros procesados
# 69370 registros procesados
# Ubigeo LAS_PALMAS: No se han contabilizado actas aún. Proyectando resultados...
# 69410 registros procesados
# 69448 registros procesados
# Ubigeo MALLORCA: No se han contabilizado actas aún. Proyectando resultados...
# 69488 registros procesados
# 69526 registros procesados
# Ubigeo TENERIFE: No se han contabilizado actas aún. Proyectando resultados...
# 69566 registros procesados
# Ubigeo VIGO: No se han contabilizado actas aún. Proyectando resultados...
# Ubigeo ZARAGOZA: No se han contabilizado actas aún. Proyectando resultados...
# 69608 registros procesados
# Ubigeo BURDEOS: No se han contabilizado actas aún. Proyectando resultados...
# Ubigeo ESTRASBURGO: No se han contabilizado actas aún. Proyectando resultados...
# 69650 registros procesados
# Ubigeo MARSELLA: No se han contabilizado actas aún. Proyectando resultados...
# 69690 registros procesados
# 69728 registros procesados
# Ubigeo TOULOUSE: No se han contabilizado actas aún. Proyectando resultados...
# 69768 registros procesados
# 69806 registros procesados
# Ubigeo ATENAS: No se han contabilizado actas aún. Proyectando resultados...
# Ubigeo GRECIA: No se han contabilizado actas aún en el nivel2. Proyectando resultados...
# 69846 registros procesados
# 69884 registros procesados
# 69922 registros procesados
# 69960 registros procesados
# 69998 registros procesados
# 70036 registros procesados
# 70074 registros procesados
# 70112 registros procesados
# Ubigeo NAPOLES: No se han contabilizado actas aún. Proyectando resultados...
# Ubigeo PERUGIA: No se han contabilizado actas aún. Proyectando resultados...
# 70154 registros procesados
# Ubigeo TRIESTE: No se han contabilizado actas aún. Proyectando resultados...
# 70194 registros procesados
# Ubigeo SKOPIE: No se han contabilizado actas aún. Proyectando resultados...
# Ubigeo MACEDONIA: No se han contabilizado actas aún en el nivel2. Proyectando resultados...
# Ubigeo LA_VALETTA: No se han contabilizado actas aún. Proyectando resultados...
# Ubigeo MALTA: No se han contabilizado actas aún en el nivel2. Proyectando resultados...
# 70236 registros procesados
# 70274 registros procesados
# 70312 registros procesados
# Ubigeo ANDORRA_LA_VELLA: No se han contabilizado actas aún. Proyectando resultados...
# Ubigeo PRINCIPADO_DE_ANDORRA: No se han contabilizado actas aún en el nivel2. Proyectando resultados...
# 70352 registros procesados
# Ubigeo BUCAREST: No se han contabilizado actas aún. Proyectando resultados...
# 70392 registros procesados
# Ubigeo MOSCU: No se han contabilizado actas aún. Proyectando resultados...
# Ubigeo RUSIA: No se han contabilizado actas aún en el nivel2. Proyectando resultados...
# Ubigeo SAN_PETERSBURGO: No se han contabilizado actas aún. Proyectando resultados...
# Ubigeo RUSIA: No se han contabilizado actas aún en el nivel2. Proyectando resultados...
# 70434 registros procesados
# 70472 registros procesados
# 70510 registros procesados
# 70548 registros procesados
# Ubigeo BRISBANE: No se han contabilizado actas aún. Proyectando resultados...
# Ubigeo AUSTRALIA: No se han contabilizado actas aún en el nivel2. Proyectando resultados...
# Ubigeo CAMBERRA: No se han contabilizado actas aún. Proyectando resultados...
# Ubigeo AUSTRALIA: No se han contabilizado actas aún en el nivel2. Proyectando resultados...
# Ubigeo MELBOURNE: No se han contabilizado actas aún. Proyectando resultados...
# Ubigeo AUSTRALIA: No se han contabilizado actas aún en el nivel2. Proyectando resultados...
# Ubigeo PERTH: No se han contabilizado actas aún. Proyectando resultados...
# Ubigeo AUSTRALIA: No se han contabilizado actas aún en el nivel2. Proyectando resultados...
# Ubigeo SIDNEY: No se han contabilizado actas aún. Proyectando resultados...
# Ubigeo AUSTRALIA: No se han contabilizado actas aún en el nivel2. Proyectando resultados...
# 70596 registros procesados
# 70634 registros procesados

# %%
df_final = df_proyeccion.groupby('nombreAgrupacionPolitica').sum(numeric_only=True).sort_values('proyeccionVotosValidos', ascending=False)
df_final.drop(index=['VOTOS EN BLANCO', 'VOTOS NULOS'], inplace=True)
df_final['porcentaje_final'] = df_final['proyeccionVotosValidos'] / df_final['proyeccionVotosValidos'].sum() * 100

# %%
consulta_total = ConsultaElectoral(eleccion=Eleccion.PRESIDENCIAL)
resumen_total = get_resultados_onpe(consulta_total, mode="resumen")['data']
actas_contabilizadas_total = resumen_total['actasContabilizadas']

# 1. Configuración estética
sns.set_theme(style="whitegrid")
plt.figure(figsize=(14, 10)) # Aumentamos un poco el ancho para que quepan las etiquetas

# 2. Dibujamos la barra de PROYECCIÓN (Fondo - el total esperado)
ax = sns.barplot(
    data=df_final,
    x='proyeccionVotosValidos',
    y='nombreAgrupacionPolitica',
    color='#A2D2FF',  # Azul claro
    label='Crecimiento Proyectado'
)

# 3. Dibujamos la barra de VOTOS ACTUALES (Encima)
sns.barplot(
    data=df_final,
    x='actualVotosValidos',
    y='nombreAgrupacionPolitica',
    color='#00308F',  # Azul oscuro
    label='Votos Actuales'
)

# 4. Personalización de etiquetas y títulos
plt.title('Votos Actuales vs. Proyección Final por Partido', fontsize=18, fontweight='bold', pad=25)
plt.xlabel('Cantidad de Votos', fontsize=13)
plt.ylabel('Agrupación Política', fontsize=13)
plt.legend(loc='lower right', frameon=True)

# 5. Añadir el texto: "Votos Totales (Porcentaje%)"
# Usamos f-strings para formatear los números con comas como separadores de miles
for i, row in enumerate(df_final.itertuples()):
    votos_totales = getattr(row, 'proyeccionVotosValidos')
    porcentaje = getattr(row, 'porcentaje_final')
    
    label_text = f'{votos_totales:,.0f} ({porcentaje:.2f}%)'
    
    plt.text(
        votos_totales + (df_final['proyeccionVotosValidos'].max() * 0.01), # Un pequeño margen a la derecha
        i, 
        label_text, 
        va='center', 
        fontsize=10, 
        fontweight='bold',
        color='#333333'
    )

plt.text(-0.5, 1.05, f"Datos obtenidos de ONPE API | Actas contabilizadas: {actas_contabilizadas_total}%",
        transform=ax.transAxes, # Usar coordenadas de ejes para que no se mueva
        ha='center', va='top', 
        fontsize=10, 
        color='black',
        fontweight='bold')

# Ajustar los límites del eje X para que las etiquetas no se corten
plt.xlim(0, df_final['proyeccionVotosValidos'].max() * 1.25)

plt.tight_layout()
plt.show()

# %% [markdown]
# +
